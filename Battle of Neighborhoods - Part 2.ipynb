# %% [markdown]
# Capstone Project - Battle of Neighbourhoods (Part 2)
#
# Introduction to the Problem
# Initial Statement. Analysis of Restaurants in Paris on the basis of its Type and Distance using Foursquare API
#
# Paris is certainly one of the best cities for food-culture in the entire Europe. There are abundant choices for various types of gourmet food in the city. There are also Michelin Star-chefs and Michelin star-restaurants. I have personally been to Paris on a number of occasions and have been amazed with the options available in the city. I always want to try out more. And I am sure, all tourists also would be hungry-for-more. One major problem that I have found is the distance of our places of residence in Paris to the locations of these fantastic restaurants. Therefore, I want to find ot the correct distances, preferably from a central location, so as to make it easy for everyone and also so that I may be able to use it during my next visit and also share it with the community.
#
# I would be using the Foursquare API, which we have learned in the previous module.
#
# In order to import the required libraries,I would run the following code:-

# %%
import numpy as np 
import pandas as pd 
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import json 
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe
# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors
# !pip install folium
import folium
# !conda install -c conda-forge geopy --yes
print('All the necessary Libraries are imported.')
# Out:
# Collecting folium
#   Downloading https://files.pythonhosted.org/packages/fd/a0/ccb3094026649cda4acd55bf2c3822bb8c277eb11446d13d384e5be35257/folium-0.10.1-py2.py3-none-any.whl (91kB)
#      |████████████████████████████████| 92kB 7.3MB/s eta 0:00:011
# Requirement already satisfied: requests in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (2.21.0)
# Collecting branca>=0.3.0 (from folium)
#   Downloading https://files.pythonhosted.org/packages/81/6d/31c83485189a2521a75b4130f1fee5364f772a0375f81afff619004e5237/branca-0.4.0-py3-none-any.whl
# Requirement already satisfied: jinja2>=2.9 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (2.10)
# Requirement already satisfied: numpy in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (1.15.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (1.24.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (2019.11.28)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: six in /opt/conda/envs/Python36/lib/python3.6/site-packages (from branca>=0.3.0->folium) (1.12.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from jinja2>=2.9->folium) (1.1.0)
# Installing collected packages: branca, folium
# Successfully installed branca-0.4.0 folium-0.10.1
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     geopy-1.21.0               |             py_0          58 KB  conda-forge
#     certifi-2019.11.28         |           py36_0         149 KB  conda-forge
#     ca-certificates-2019.11.28 |       hecc5488_0         145 KB  conda-forge
#     openssl-1.1.1d             |       h516909a_0         2.1 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.5 MB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib:   1.50-py_0         conda-forge
#     geopy:           1.21.0-py_0       conda-forge
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2019.11.27-0                  --> 2019.11.28-hecc5488_0 conda-forge
#     certifi:         2019.11.28-py36_0             --> 2019.11.28-py36_0     conda-forge
#
# The following packages will be DOWNGRADED:
#
#     openssl:         1.1.1d-h7b6447c_3             --> 1.1.1d-h516909a_0     conda-forge
#
#
# Downloading and Extracting Packages
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# geopy-1.21.0         | 58 KB     | ##################################### | 100%
# certifi-2019.11.28   | 149 KB    | ##################################### | 100%
# ca-certificates-2019 | 145 KB    | ##################################### | 100%
# openssl-1.1.1d       | 2.1 MB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# All the necessary Libraries are imported.

# %% [markdown]
# Now, in order to obtain the accurate coordinates of Pairs, I would run the following code:-

# %%
address = 'Paris, Paris'
geolocator = Nominatim(user_agent="paris_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinates of Paris are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinates of Paris are 48.8566969, 2.3514616.

# %% [markdown]
# For setting up my Foursquare API with my personlised ID, I would run the following code:-

# %%
CLIENT_ID = '5QSFCGKQQQN3R5SSWMO1ZOQ3IBDB0R52RQLDEHZCSYTWZGBJ' # your Foursquare ID
CLIENT_SECRET = '0JCF4PLZVQGBN0YL1BEXK0RSNTL0D03VXJ1C3V4GWUNX1MDZ' # your Foursquare Secret
VERSION = '202001218' # Foursquare API version
LIMIT = 100
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: 5QSFCGKQQQN3R5SSWMO1ZOQ3IBDB0R52RQLDEHZCSYTWZGBJ
# CLIENT_SECRET:0JCF4PLZVQGBN0YL1BEXK0RSNTL0D03VXJ1C3V4GWUNX1MDZ

# %% [markdown]
# Now I need to specify the restaurant-query. For that:-

# %%
search_query = 'Restaurant'
radius = 50000
print(search_query + ' .... Done!')
# Out:
# Restaurant .... Done!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=5QSFCGKQQQN3R5SSWMO1ZOQ3IBDB0R52RQLDEHZCSYTWZGBJ&client_secret=0JCF4PLZVQGBN0YL1BEXK0RSNTL0D03VXJ1C3V4GWUNX1MDZ&ll=48.8566969,2.3514616&v=202001218&query=Restaurant&radius=50000&limit=100'

# %%
results = requests.get(url).json()
venues = results['response']['venues']
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d10c941735', 'name': 'F...    False
# 1  [{'id': '4bf58dd8d48988d10c941735', 'name': 'F...    False
# 2  [{'id': '4bf58dd8d48988d10c941735', 'name': 'F...    False
# 3  [{'id': '4bf58dd8d48988d10c941735', 'name': 'F...    False
# 4  [{'id': '4bf58dd8d48988d10c941735', 'name': 'F...    False
#
#                          id              location.address location.cc  \
# 0  50445ef7e4b0ba0a539ad83f               23 rue d'Arcole          FR
# 1  4e2b2d0ad22d3f83c88c7029            12 passage Molière          FR
# 2  4cbb05054352a1cd0d4396f5  1 rue de la Légion d'Honneur          FR
# 3  52cf091111d2d9bb920d6122                  Hôtel Costes          FR
# 4  4d4960ae9544a09370bb27e7              91 rue La Boétie          FR
#
#   location.city location.country  location.crossStreet  location.distance  \
# 0         Paris           France                   NaN                373
# 1         Paris           France                   NaN                626
# 2         Paris           France                   NaN               1950
# 3         Paris           France  239 rue Saint-Honoré               2053
# 4         Paris           France                   NaN               1343
#
#                            location.formattedAddress  \
# 0             [23 rue d'Arcole, 75004 Paris, France]
# 1          [12 passage Molière, 75003 Paris, France]
# 2  [1 rue de la Légion d'Honneur, 75007 Paris, Fr...
# 3  [Hôtel Costes (239 rue Saint-Honoré), Paris, F...
# 4            [91 rue La Boétie, 75008 Paris, France]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 48.85362193008465...     48.853622
# 1  [{'label': 'display', 'lat': 48.86232131013030...     48.862321
# 2  [{'label': 'display', 'lat': 48.86029986248957...     48.860300
# 3  [{'label': 'display', 'lat': 48.86669789450374...     48.866698
# 4  [{'label': 'display', 'lat': 48.85568519411101...     48.855685
#
#    location.lng location.neighborhood location.postalCode location.state  \
# 0      2.349421                   NaN               75004  Île-de-France
# 1      2.351590                   NaN               75003  Île-de-France
# 2      2.325392                   NaN               75007  Île-de-France
# 3      2.327894                   NaN                 NaN  Île-de-France
# 4      2.333184                   NaN               75008  Île-de-France
#
#                                  name    referralId venuePage.id
# 0  Restaurant Aux Tours de Notre-Dame  v-1583356324          NaN
# 1            Le Restaurant des Poètes  v-1583356324          NaN
# 2      Le Restaurant du Musée d'Orsay  v-1583356324          NaN
# 3      Restaurant Costes Saint-Honoré  v-1583356324          NaN
# 4                    Restaurant Au 35  v-1583356324          NaN

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_paris = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_paris['categories'] = dataframe_paris.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_paris.columns = [column.split('.')[-1] for column in dataframe_paris.columns]

dataframe_paris.head(10)
# Out:
#                                        name                 categories  \
# 0        Restaurant Aux Tours de Notre-Dame          French Restaurant
# 1                  Le Restaurant des Poètes          French Restaurant
# 2            Le Restaurant du Musée d'Orsay          French Restaurant
# 3            Restaurant Costes Saint-Honoré          French Restaurant
# 4                          Restaurant Au 35          French Restaurant
# 5                   Restaurant Le Mona Lisa          French Restaurant
# 6  Restaurant de l'Institut du Monde Arabe.  Middle Eastern Restaurant
# 7                 Restaurant 58 Tour Eiffel          French Restaurant
# 8       Restaurant Le Meurice Alain Ducasse          French Restaurant
# 9                  Le Restaurant de L'Hôtel          French Restaurant
#
#                           address  cc   city country              crossStreet  \
# 0                 23 rue d'Arcole  FR  Paris  France                      NaN
# 1              12 passage Molière  FR  Paris  France                      NaN
# 2    1 rue de la Légion d'Honneur  FR  Paris  France                      NaN
# 3                    Hôtel Costes  FR  Paris  France     239 rue Saint-Honoré
# 4                91 rue La Boétie  FR  Paris  France                      NaN
# 5                   47 rue Berger  FR  Paris  France                      NaN
# 6  1 rue des Fossés Saint-Bernard  FR  Paris  France  Institut du Monde Arabe
# 7         5 avenue Anatole France  FR  Paris  France   Tour Eiffel, 1er étage
# 8               228 rue de Rivoli  FR  Paris  France         Hôtel Le Meurice
# 9           13 rue des Beaux-Arts  FR  Paris  France                  L'Hôtel
#
#    distance                                   formattedAddress  \
# 0       373             [23 rue d'Arcole, 75004 Paris, France]
# 1       626          [12 passage Molière, 75003 Paris, France]
# 2      1950  [1 rue de la Légion d'Honneur, 75007 Paris, Fr...
# 3      2053  [Hôtel Costes (239 rue Saint-Honoré), Paris, F...
# 4      1343            [91 rue La Boétie, 75008 Paris, France]
# 5       895               [47 rue Berger, 75001 Paris, France]
# 6       963  [1 rue des Fossés Saint-Bernard (Institut du M...
# 7      4194  [5 avenue Anatole France (Tour Eiffel, 1er éta...
# 8      1963  [228 rue de Rivoli (Hôtel Le Meurice), 75001 P...
# 9      1197  [13 rue des Beaux-Arts (L'Hôtel), 75006 Paris,...
#
#                                       labeledLatLngs        lat       lng  \
# 0  [{'label': 'display', 'lat': 48.85362193008465...  48.853622  2.349421
# 1  [{'label': 'display', 'lat': 48.86232131013030...  48.862321  2.351590
# 2  [{'label': 'display', 'lat': 48.86029986248957...  48.860300  2.325392
# 3  [{'label': 'display', 'lat': 48.86669789450374...  48.866698  2.327894
# 4  [{'label': 'display', 'lat': 48.85568519411101...  48.855685  2.333184
# 5  [{'label': 'display', 'lat': 48.86219809159731...  48.862198  2.342542
# 6  [{'label': 'display', 'lat': 48.84881796195433...  48.848818  2.356911
# 7  [{'label': 'display', 'lat': 48.85836582402155...  48.858366  2.294249
# 8  [{'label': 'display', 'lat': 48.86529145109384...  48.865291  2.328056
# 9  [{'label': 'display', 'lat': 48.85619157441753...  48.856192  2.335133
#
#   neighborhood postalCode          state                        id
# 0          NaN      75004  Île-de-France  50445ef7e4b0ba0a539ad83f
# 1          NaN      75003  Île-de-France  4e2b2d0ad22d3f83c88c7029
# 2          NaN      75007  Île-de-France  4cbb05054352a1cd0d4396f5
# 3          NaN        NaN  Île-de-France  52cf091111d2d9bb920d6122
# 4          NaN      75008  Île-de-France  4d4960ae9544a09370bb27e7
# 5          NaN      75001  Île-de-France  59ab059c86bc49021b313ca9
# 6          NaN      75005  Île-de-France  4bd1e55c9854d13a2c79fa4d
# 7          NaN      75007  Île-de-France  4e078807e4cdefcff6dce4f6
# 8          NaN      75001  Île-de-France  4adcda13f964a520e53621e3
# 9          NaN      75006  Île-de-France  4bbcc19b8ec3d13aa42e1b28

# %% [markdown]
# Data has now been collected and I am ready to proceed.
#
# Let's see Paris

# %%
import matplotlib. pyplot as plt
# !pip install folium
import folium
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13)
venues_map
# Out:
# Requirement already satisfied: folium in /opt/conda/envs/Python36/lib/python3.6/site-packages (0.10.1)
# Requirement already satisfied: branca>=0.3.0 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (0.4.0)
# Requirement already satisfied: requests in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (2.21.0)
# Requirement already satisfied: numpy in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (1.15.4)
# Requirement already satisfied: jinja2>=2.9 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (2.10)
# Requirement already satisfied: six in /opt/conda/envs/Python36/lib/python3.6/site-packages (from branca>=0.3.0->folium) (1.12.0)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (1.24.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (2019.11.28)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from jinja2>=2.9->folium) (1.1.0)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# In this maze, where arenour restaurants. Lets highlight them in Red colour.

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generates a map centred around the City of Paris
for lat, lng, label in zip(dataframe_paris.lat, dataframe_paris.lng, dataframe_paris.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='red',
        popup=label,
        fill = True,
        fill_color='red',
        fill_opacity=0.6
    ).add_to(venues_map)
# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Now we can clearly visualise our restaurants.

# %%
print (dataframe_paris['categories'].value_counts())
# Out:
# French Restaurant            21
# Restaurant                    3
# College Cafeteria             3
# Middle Eastern Restaurant     2
# Japanese Restaurant           2
# Turkish Restaurant            2
# Szechuan Restaurant           2
# Vietnamese Restaurant         2
# City Hall                     1
# Kebab Restaurant              1
# Italian Restaurant            1
# Corporate Cafeteria           1
# Cafeteria                     1
# Thai Restaurant               1
# Sandwich Place                1
# Persian Restaurant            1
# Hotel Bar                     1
# Bistro                        1
# Chinese Restaurant            1
# Fast Food Restaurant          1
# Korean Restaurant             1
# Name: categories, dtype: int64

# %% [markdown]
# Paris does have a very huge number of restaurants to cater to all of us
#
# Let's get our Pandas

# %%
Paris_Top = dataframe_paris['categories'].value_counts()[0:10].to_frame(name='frequency')
Paris_Top=Paris_Top.reset_index()


Paris_Top.rename(index=str, columns={"index": "categories", "frequency": "Frequency"}, inplace=True)
Paris_Top
# Out:
#                   categories  Frequency
# 0          French Restaurant         21
# 1                 Restaurant          3
# 2          College Cafeteria          3
# 3  Middle Eastern Restaurant          2
# 4        Japanese Restaurant          2
# 5         Turkish Restaurant          2
# 6        Szechuan Restaurant          2
# 7      Vietnamese Restaurant          2
# 8                  City Hall          1
# 9           Kebab Restaurant          1

# %% [markdown]
# Let's Visualize this Information in the form of a Bar Chart by using the Seaborn Data Visualization Library

# %%
import seaborn as sns
fig = plt.figure(figsize=(18,7))
s=sns.barplot(x="categories", y="Frequency", data=Paris_Top)
s.set_xticklabels(s.get_xticklabels(), rotation=30)
plt.title('10 Most Frequently Occuring Types of Restaurants in Paris', fontsize=15)
plt.xlabel("categories", fontsize=15)
plt.ylabel ("Frequency", fontsize=15)
plt.show()

# %% [markdown]
# Let us make this information a bit user friendly

# %%
FR=dataframe_paris['name']
FR=FR.reset_index()
FR.head(30)
# Out:
#     index                                             name
# 0       0               Restaurant Aux Tours de Notre-Dame
# 1       1                         Le Restaurant des Poètes
# 2       2                   Le Restaurant du Musée d'Orsay
# 3       3                   Restaurant Costes Saint-Honoré
# 4       4                                 Restaurant Au 35
# 5       5                          Restaurant Le Mona Lisa
# 6       6         Restaurant de l'Institut du Monde Arabe.
# 7       7                        Restaurant 58 Tour Eiffel
# 8       8              Restaurant Le Meurice Alain Ducasse
# 9       9                         Le Restaurant de L'Hôtel
# 10     10                        Le Grand Amour Restaurant
# 11     11                   Restaurant Hotel Little Palace
# 12     12                                 Elise Restaurant
# 13     13                         Restaurant administratif
# 14     14        Restaurant universitaire Crous de Censier
# 15     15                             Restaurant Ayào.阿耀面点
# 16     16             Restaurant de Bourgogne Chez Maurice
# 17     17                           Restaurant Mon Paris !
# 18     18                               Restaurant Sichuan
# 19     19                                  Restaurant Viet
# 20     20                                Restaurant Deluxe
# 21     21                Restaurant universitaire Châtelet
# 22     22                       Restaurant du Montalembert
# 23     23                          Restaurant Mediterranée
# 24     24                       Restaurant Le Robinet d'Or
# 25     25                                Restaurant Coréen
# 26     26                     Restaurant Jardin Notre-Dame
# 27     27                          Restaurant d'Entreprise
# 28     28                 Restaurant Cercle des Directeurs
# 29     29  Restaurant Universitaire  - Cité internationale

# %%
FR2=dataframe_paris['categories']
FR2=FR2.reset_index()
FR2.head(30)
# Out:
#     index                 categories
# 0       0          French Restaurant
# 1       1          French Restaurant
# 2       2          French Restaurant
# 3       3          French Restaurant
# 4       4          French Restaurant
# 5       5          French Restaurant
# 6       6  Middle Eastern Restaurant
# 7       7          French Restaurant
# 8       8          French Restaurant
# 9       9          French Restaurant
# 10     10                 Restaurant
# 11     11                 Restaurant
# 12     12         Turkish Restaurant
# 13     13                 Restaurant
# 14     14          College Cafeteria
# 15     15         Chinese Restaurant
# 16     16          French Restaurant
# 17     17          French Restaurant
# 18     18        Szechuan Restaurant
# 19     19      Vietnamese Restaurant
# 20     20         Turkish Restaurant
# 21     21          College Cafeteria
# 22     22                  Hotel Bar
# 23     23       Fast Food Restaurant
# 24     24                     Bistro
# 25     25          Korean Restaurant
# 26     26          French Restaurant
# 27     27                  Cafeteria
# 28     28        Corporate Cafeteria
# 29     29          College Cafeteria

# %%
FR3= (pd.merge(FR, FR2, on="index" ))
FR3.head(40)
# Out:
#     index                                               name  \
# 0       0                 Restaurant Aux Tours de Notre-Dame
# 1       1                           Le Restaurant des Poètes
# 2       2                     Le Restaurant du Musée d'Orsay
# 3       3                     Restaurant Costes Saint-Honoré
# 4       4                                   Restaurant Au 35
# 5       5                            Restaurant Le Mona Lisa
# 6       6           Restaurant de l'Institut du Monde Arabe.
# 7       7                          Restaurant 58 Tour Eiffel
# 8       8                Restaurant Le Meurice Alain Ducasse
# 9       9                           Le Restaurant de L'Hôtel
# 10     10                          Le Grand Amour Restaurant
# 11     11                     Restaurant Hotel Little Palace
# 12     12                                   Elise Restaurant
# 13     13                           Restaurant administratif
# 14     14          Restaurant universitaire Crous de Censier
# 15     15                               Restaurant Ayào.阿耀面点
# 16     16               Restaurant de Bourgogne Chez Maurice
# 17     17                             Restaurant Mon Paris !
# 18     18                                 Restaurant Sichuan
# 19     19                                    Restaurant Viet
# 20     20                                  Restaurant Deluxe
# 21     21                  Restaurant universitaire Châtelet
# 22     22                         Restaurant du Montalembert
# 23     23                            Restaurant Mediterranée
# 24     24                         Restaurant Le Robinet d'Or
# 25     25                                  Restaurant Coréen
# 26     26                       Restaurant Jardin Notre-Dame
# 27     27                            Restaurant d'Entreprise
# 28     28                   Restaurant Cercle des Directeurs
# 29     29    Restaurant Universitaire  - Cité internationale
# 30     30                                   Restaurant Shiso
# 31     31                                      Restaurant AT
# 32     32                                 Jet Set Restaurant
# 33     33                               Restaurant Le Sinner
# 34     34                           Restaurant Alain Ducasse
# 35     35                               Restaurant Istamboul
# 36     36                           Restaurant du Rond-Point
# 37     37  Hôtel de Ville de Paris (Hôtel de ville de Paris)
# 38     38                                 BLOSSOM Restaurant
# 39     39                       Restaurant Vietnam | Banh Mi
#
#                    categories
# 0           French Restaurant
# 1           French Restaurant
# 2           French Restaurant
# 3           French Restaurant
# 4           French Restaurant
# 5           French Restaurant
# 6   Middle Eastern Restaurant
# 7           French Restaurant
# 8           French Restaurant
# 9           French Restaurant
# 10                 Restaurant
# 11                 Restaurant
# 12         Turkish Restaurant
# 13                 Restaurant
# 14          College Cafeteria
# 15         Chinese Restaurant
# 16          French Restaurant
# 17          French Restaurant
# 18        Szechuan Restaurant
# 19      Vietnamese Restaurant
# 20         Turkish Restaurant
# 21          College Cafeteria
# 22                  Hotel Bar
# 23       Fast Food Restaurant
# 24                     Bistro
# 25          Korean Restaurant
# 26          French Restaurant
# 27                  Cafeteria
# 28        Corporate Cafeteria
# 29          College Cafeteria
# 30        Japanese Restaurant
# 31        Japanese Restaurant
# 32         Persian Restaurant
# 33          French Restaurant
# 34          French Restaurant
# 35             Sandwich Place
# 36          French Restaurant
# 37                  City Hall
# 38          French Restaurant
# 39      Vietnamese Restaurant

# %% [markdown]
# We should now have all our required data.

# %%
FR3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 0 to 49
# Data columns (total 3 columns):
# index         50 non-null int64
# name          50 non-null object
# categories    50 non-null object
# dtypes: int64(1), object(2)
# memory usage: 1.6+ KB

# %%
FR4=dataframe_paris['distance']
FR4=FR4.reset_index()
FR4.head(40)
# Out:
#     index  distance
# 0       0       373
# 1       1       626
# 2       2      1950
# 3       3      2053
# 4       4      1343
# 5       5       895
# 6       6       963
# 7       7      4194
# 8       8      1963
# 9       9      1197
# 10     10      2020
# 11     11      1201
# 12     12      1567
# 13     13      1186
# 14     14      1353
# 15     15      2294
# 16     16      2023
# 17     17      2262
# 18     18      2030
# 19     19       131
# 20     20      1722
# 21     21      1764
# 22     22      1739
# 23     23      1769
# 24     24      2566
# 25     25      1837
# 26     26       573
# 27     27      1799
# 28     28      2587
# 29     29      4309
# 30     30       330
# 31     31       820
# 32     32      4010
# 33     33       863
# 34     34      3618
# 35     35       396
# 36     36      3239
# 37     37        71
# 38     38      2554
# 39     39      2521

# %%
FR4.drop(columns='index')
# Out:
#     distance
# 0        373
# 1        626
# 2       1950
# 3       2053
# 4       1343
# 5        895
# 6        963
# 7       4194
# 8       1963
# 9       1197
# 10      2020
# 11      1201
# 12      1567
# 13      1186
# 14      1353
# 15      2294
# 16      2023
# 17      2262
# 18      2030
# 19       131
# 20      1722
# 21      1764
# 22      1739
# 23      1769
# 24      2566
# 25      1837
# 26       573
# 27      1799
# 28      2587
# 29      4309
# 30       330
# 31       820
# 32      4010
# 33       863
# 34      3618
# 35       396
# 36      3239
# 37        71
# 38      2554
# 39      2521
# 40       775
# 41       885
# 42      1712
# 43       713
# 44      2702
# 45      1056
# 46       603
# 47      2899
# 48       990
# 49      3918

# %% [markdown]
# Let us now make these two tables useful at one glance

# %%
FR5= (pd.merge(FR3, FR4, on='index'))
FR5.head(40)
# Out:
#     index                                               name  \
# 0       0                 Restaurant Aux Tours de Notre-Dame
# 1       1                           Le Restaurant des Poètes
# 2       2                     Le Restaurant du Musée d'Orsay
# 3       3                     Restaurant Costes Saint-Honoré
# 4       4                                   Restaurant Au 35
# 5       5                            Restaurant Le Mona Lisa
# 6       6           Restaurant de l'Institut du Monde Arabe.
# 7       7                          Restaurant 58 Tour Eiffel
# 8       8                Restaurant Le Meurice Alain Ducasse
# 9       9                           Le Restaurant de L'Hôtel
# 10     10                          Le Grand Amour Restaurant
# 11     11                     Restaurant Hotel Little Palace
# 12     12                                   Elise Restaurant
# 13     13                           Restaurant administratif
# 14     14          Restaurant universitaire Crous de Censier
# 15     15                               Restaurant Ayào.阿耀面点
# 16     16               Restaurant de Bourgogne Chez Maurice
# 17     17                             Restaurant Mon Paris !
# 18     18                                 Restaurant Sichuan
# 19     19                                    Restaurant Viet
# 20     20                                  Restaurant Deluxe
# 21     21                  Restaurant universitaire Châtelet
# 22     22                         Restaurant du Montalembert
# 23     23                            Restaurant Mediterranée
# 24     24                         Restaurant Le Robinet d'Or
# 25     25                                  Restaurant Coréen
# 26     26                       Restaurant Jardin Notre-Dame
# 27     27                            Restaurant d'Entreprise
# 28     28                   Restaurant Cercle des Directeurs
# 29     29    Restaurant Universitaire  - Cité internationale
# 30     30                                   Restaurant Shiso
# 31     31                                      Restaurant AT
# 32     32                                 Jet Set Restaurant
# 33     33                               Restaurant Le Sinner
# 34     34                           Restaurant Alain Ducasse
# 35     35                               Restaurant Istamboul
# 36     36                           Restaurant du Rond-Point
# 37     37  Hôtel de Ville de Paris (Hôtel de ville de Paris)
# 38     38                                 BLOSSOM Restaurant
# 39     39                       Restaurant Vietnam | Banh Mi
#
#                    categories  distance
# 0           French Restaurant       373
# 1           French Restaurant       626
# 2           French Restaurant      1950
# 3           French Restaurant      2053
# 4           French Restaurant      1343
# 5           French Restaurant       895
# 6   Middle Eastern Restaurant       963
# 7           French Restaurant      4194
# 8           French Restaurant      1963
# 9           French Restaurant      1197
# 10                 Restaurant      2020
# 11                 Restaurant      1201
# 12         Turkish Restaurant      1567
# 13                 Restaurant      1186
# 14          College Cafeteria      1353
# 15         Chinese Restaurant      2294
# 16          French Restaurant      2023
# 17          French Restaurant      2262
# 18        Szechuan Restaurant      2030
# 19      Vietnamese Restaurant       131
# 20         Turkish Restaurant      1722
# 21          College Cafeteria      1764
# 22                  Hotel Bar      1739
# 23       Fast Food Restaurant      1769
# 24                     Bistro      2566
# 25          Korean Restaurant      1837
# 26          French Restaurant       573
# 27                  Cafeteria      1799
# 28        Corporate Cafeteria      2587
# 29          College Cafeteria      4309
# 30        Japanese Restaurant       330
# 31        Japanese Restaurant       820
# 32         Persian Restaurant      4010
# 33          French Restaurant       863
# 34          French Restaurant      3618
# 35             Sandwich Place       396
# 36          French Restaurant      3239
# 37                  City Hall        71
# 38          French Restaurant      2554
# 39      Vietnamese Restaurant      2521

# %%
FR6 = FR5.sort_values(by ='distance' )
FR6.head(20)
# Out:
#     index                                               name  \
# 37     37  Hôtel de Ville de Paris (Hôtel de ville de Paris)
# 19     19                                    Restaurant Viet
# 30     30                                   Restaurant Shiso
# 0       0                 Restaurant Aux Tours de Notre-Dame
# 35     35                               Restaurant Istamboul
# 26     26                       Restaurant Jardin Notre-Dame
# 46     46                Restaurant Les Degrés de Notre Dame
# 1       1                           Le Restaurant des Poètes
# 43     43                           Restaurant AG Les Halles
# 40     40                       Restaurant Mae Nam Choapraya
# 31     31                                      Restaurant AT
# 33     33                               Restaurant Le Sinner
# 41     41                                     Restaurant Erh
# 5       5                            Restaurant Le Mona Lisa
# 6       6           Restaurant de l'Institut du Monde Arabe.
# 48     48                                   Restaurant Pacha
# 45     45                                Restaurant Le Luigi
# 13     13                           Restaurant administratif
# 9       9                           Le Restaurant de L'Hôtel
# 11     11                     Restaurant Hotel Little Palace
#
#                    categories  distance
# 37                  City Hall        71
# 19      Vietnamese Restaurant       131
# 30        Japanese Restaurant       330
# 0           French Restaurant       373
# 35             Sandwich Place       396
# 26          French Restaurant       573
# 46          French Restaurant       603
# 1           French Restaurant       626
# 43          French Restaurant       713
# 40            Thai Restaurant       775
# 31        Japanese Restaurant       820
# 33          French Restaurant       863
# 41          French Restaurant       885
# 5           French Restaurant       895
# 6   Middle Eastern Restaurant       963
# 48           Kebab Restaurant       990
# 45         Italian Restaurant      1056
# 13                 Restaurant      1186
# 9           French Restaurant      1197
# 11                 Restaurant      1201

# %% [markdown]
# Let's sample check our results now

# %%
FR6.head(10)
# Out:
#     index                                               name  \
# 37     37  Hôtel de Ville de Paris (Hôtel de ville de Paris)
# 19     19                                    Restaurant Viet
# 30     30                                   Restaurant Shiso
# 0       0                 Restaurant Aux Tours de Notre-Dame
# 35     35                               Restaurant Istamboul
# 26     26                       Restaurant Jardin Notre-Dame
# 46     46                Restaurant Les Degrés de Notre Dame
# 1       1                           Le Restaurant des Poètes
# 43     43                           Restaurant AG Les Halles
# 40     40                       Restaurant Mae Nam Choapraya
#
#                categories  distance
# 37              City Hall        71
# 19  Vietnamese Restaurant       131
# 30    Japanese Restaurant       330
# 0       French Restaurant       373
# 35         Sandwich Place       396
# 26      French Restaurant       573
# 46      French Restaurant       603
# 1       French Restaurant       626
# 43      French Restaurant       713
# 40        Thai Restaurant       775

# %% [markdown]
# We should also see them graphically for a better overview

# %%
fig = plt.figure(figsize=(28,10))
s=sns.barplot(x="categories", y="distance",  data=FR6)
s.set_xticklabels(s.get_xticklabels(), rotation=30)
plt.title('Restaurants in Paris on the basis of distance', fontsize=25)
plt.xlabel("categories", fontsize=15)
plt.ylabel ("Distance", fontsize=15)
plt.show()

# %%
FR7= FR6.copy()
FR7[:10]
# Out:
#     index                                               name  \
# 37     37  Hôtel de Ville de Paris (Hôtel de ville de Paris)
# 19     19                                    Restaurant Viet
# 30     30                                   Restaurant Shiso
# 0       0                 Restaurant Aux Tours de Notre-Dame
# 35     35                               Restaurant Istamboul
# 26     26                       Restaurant Jardin Notre-Dame
# 46     46                Restaurant Les Degrés de Notre Dame
# 1       1                           Le Restaurant des Poètes
# 43     43                           Restaurant AG Les Halles
# 40     40                       Restaurant Mae Nam Choapraya
#
#                categories  distance
# 37              City Hall        71
# 19  Vietnamese Restaurant       131
# 30    Japanese Restaurant       330
# 0       French Restaurant       373
# 35         Sandwich Place       396
# 26      French Restaurant       573
# 46      French Restaurant       603
# 1       French Restaurant       626
# 43      French Restaurant       713
# 40        Thai Restaurant       775

# %%
fig = plt.figure(figsize=(28,10))
s=sns.barplot(x="categories", y="distance",  data=FR7[:10])
s.set_xticklabels(s.get_xticklabels(), rotation=30)
plt.title('Top 10 Restaurants in Paris on the basis of distance', fontsize=25)
plt.xlabel("categories", fontsize=15)
plt.ylabel ("Distance", fontsize=15)
plt.show()

# %% [markdown]
# Comparing the two bar-graphs, this looks more user friendly. It can be ascertained that Vietnamese, Japanese, French and Sandwich Place are the most suitable
#
# Whenever I visit any new country, where to stay and where to eat are always issues in front of tourists. ere, I have focussed on the where to eat part of the issue. I am certain that every tourist would like to have such information at hand so as to use his time and, more importantly, his money in an optimal manner.
